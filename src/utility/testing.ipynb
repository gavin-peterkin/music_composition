# %%
from s3_mongo_inter import S3MongoInterface

# %%
test = S3MongoInterface()

# %%
for fn, data, key in test.pull_midi_data({}):
    pass

# %%
fn
# Out:
# u'IMSLP149391-WIMA.9989-onsloeco.mid'

# %%
key
# Out:
# u'E\u266d major'

# %%
data.read()
# Out:
# 'MThd\x00\x00\x00\x06\x00\x01\x00\t\x00\xc0MTrk\x00\x00\x02\x16\x00\xffQ\x03\x0bq\xb0\x00\xffX\x04\x06\x03\x18\x08\x83`\xffQ\x03\x10\x0f\xd70\xffQ\x03\r\x146\x91P\xffQ\x03\x10\x0f\xd70\xffQ\x03\r\x146\x91P\xffQ\x03\rD\xbd0\xffQ\x03\r\x146\x90\x10\xffQ\x03\x0eN\x1c\x82 \xffQ\x03\r\x146\x83`\xffQ\x03-\xc6\xc0\x18\xffQ\x03\x14\xce\xb4H\xffQ\x03\r\x146\x8c\x00\xffQ\x03\x0e\x88<`\xffQ\x03\rD\xbd0\xffQ\x03\r\x146\x90\x10\xffQ\x03\x0eN\x1c\x82 \xffQ\x03\r\x146\x83`\xffQ\x03-\xc6\xc0\x18\xffQ\x03\x14\xce\xb4H\xffQ\x03\r\x146\x8c\x00\xffQ\x03\x0e\x88<`\xffQ\x03\r\x146`\xffQ\x03\r\x146\x8d@\xffQ\x03\x0eN\x1c\x81\x10\xffQ\x03\x0e\xc4=\x82P\xffQ\x03\r\x146`\xffQ\x03\r\x146\x8d@\xffQ\x03\x0eN\x1c\x81\x10\xffQ\x03\x0e\xc4=\x82P\xffQ\x03\r\x146\xa10\xffQ\x03\x0eN\x1c\x82P\xffQ\x03\r\x146\xa10\xffQ\x03\x0eN\x1c\x82P\xffQ\x03\r\x146\xa4`\xffQ\x03\x0c\xe5\x0e\x89\x00\xffQ\x03\r\x146\x92\x00\xffQ\x03\x0c\xe5\x0e\x89\x00\xffQ\x03\x0c\xe5\x0e\x89\x00\xffQ\x03\r\x146\x92\x00\xffQ\x03\x0c\xe5\x0e\x87p\xffQ
# ...

# %%
# Out:
# Dumped url data: http://ks.imslp.net/files/imglnks/usimg/d/dc/IMSLP149391-WIMA.9989-onsloeco.mid
# Dumped url data: http://ks.imslp.net/files/imglnks/usimg/d/d8/IMSLP474892-PMLP770666-Benaut_Malbruck.mid
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-b92627563fbc> in <module>()
# ----> 1 test._execute_midi_dumps()
#
# /Users/gavinpeterkin/workspace/music_composition/src/scraping/download/placeholder.py in _execute_midi_dumps(self)
#      72             for download_url in doc['download_urls']:
#      73                 if download_url[-4:] == '.mid':
# ---> 74                     self._insert_new_midi(doc['_id'], download_url)
#      75                 break
#
# /Users/gavinpeterkin/workspace/music_composition/src/scraping/download/placeholder.py in _insert_new_midi(self, _id, download_url)
#      43             pass
#      44         else:
# ...
