# %%
from utility.playback import Playback
from parsing.midi_parser import MidiParser

# %%
with open('/Users/gavinpeterkin/Downloads/test.mid', 'rb') as f:
    test_midi_data = f.read()

parsed_midi = MidiParser(test_midi_data, 'G major')

# %%
parsed_midi.list_of_notes
# Out:
# [[],
#  [(67, 'b')],
#  [(67, 's')],
#  [(43, 'b'), (55, 'b'), (62, 'b'), (71, 'b')],
#  [(43, 's'), (55, 's'), (62, 's'), (71, 's')],
#  [(43, 's'), (55, 's'), (62, 's'), (71, 's')],
#  [(43, 's'), (55, 's'), (62, 's'), (71, 's')],
#  [(43, 'b'), (55, 'b'), (62, 'b'), (71, 'b')],
#  [(43, 's'), (55, 's'), (62, 's'), (71, 's')],
#  [(43, 'b'), (55, 'b'), (62, 'b'), (71, 'b')],
#  [(43, 's'), (55, 's'), (62, 's'), (71, 's')],
#  [(43, 's'), (55, 's'), (62, 's'), (71, 's')],
#  [(43, 's'), (55, 's'), (62, 's'), (71, 's')],
#  [(42, 'b'), (54, 'b'), (62, 'b'), (69, 'b')],
#  [(42, 's'), (54, 's'), (62, 's'), (69, 's')],
#  [(54, 's'), (69, 's')],
#  [(40, 'b'), (52, 'b'), (67, 'b'), (72, 'b')],
#  [(40, 's'), (52, 's'), (67, 's'), (72, 's')],
#  [(40, 'b'), (52, 'b'), (67, 's'), (72, 's')],
#  [(40, 's'), (52, 's'), (67, 's'), (72, 's')],
#  [(52, 's'), (67, 's'), (72, 's')],
#  [(42, 'b'), (54, 'b'), (67, 's'), (72, 's')],
#  [(42, 's'), (54, 's'), (67, 's'), (72, 's')],
#  [(54, 's'), (67, 's'), (72, 's')],
#  [(43, 'b'), (55, 'b'), (67, 'b'), (71, 'b')],
#  [(43, 's'), (55, 's'), (67, 's'), (71, 's')],
#  [(43, 's'), (55, 's'), (67, 's'), (71, 's')],
#  [(43, 's'), (55, 's'), (69, 'b'), (72, 'b')],
#  [(43, 's'), (55, 's'), (72, 's')],
#  [(43, 'b'), (55, 'b'), (67, 'b'), (71, 'b')],
#  [(43, 's'), (55, 's'), (67, 's'), (71, 's')],
#  [(55, 's'), (71, 's')],
#  [(38, 'b'), (50, 'b'), (66, 'b'), (69, 'b')],
#  [(38, 's'), (50, 's'), (66, 's'), (69, 's')],
#  [(38, 's'), (50, 's'), (66, 's'), (69, 's')],
#  [(38, 's'), (50, 's'), (66, 's'), (69, 's')],
#  [(38, 'b'), (50, 'b'), (66, 'b'), (69, 'b')],
#  [(38, 's'), (50, 's'), (66, 's'), (69, 's')],
#  [(38, 'b'), (50, 'b'), (66, 'b'), (69, 'b')],
#  [(38, 's'), (50, 's'), (66, 's'), (69, 's')],
#  [(38, 's'), (50, 's'), (66, 's'), (69, 's')],
#  [(38, 's'), (50, 's'), (64, 'b'), (67, 'b')],
#  [(38, 's'), (50, 's'), (67, 's')],
#  [(38, 'b'), (50, 'b'), (66, 'b'), (69, 'b')],
#  [(38, 's'), (50, 's'), (66, 's'), (69, 's')],
#  [(50, 's'), (69, 's')],
#  [(31, 'b'), (43, 'b'), (67, 'b'), (71, 'b')],
#  [(31, 's'), (43, 's'), (67, 's'), (71, 's')],
#  [(43, 's'), (67, 's'), (71, 's')],
#  [(35, 'b'), (43, 's'), (67, 's'), (71, 's')],
#  [(35, 's'), (43, 's'), (67, 's'), (71, 's')],
#  [(43, 's'), (67, 's'), (71, 's')],
#  [(31, 'b'), (43, 's'), (67, 's'), (71, 's')],
#  [(31, 's'), (43, 's'), (67, 's'), (71, 's')],
#  [(43, 's'), (67, 's'), (71, 's')],
#  [(38, 'b'), (50, 'b'), (66, 'b'), (67, 's'), (69, 'b')],
#  [(38, 's'), (50, 's'), (66, 's'), (69, 's')],
#  [(38, 's'), (50, 's'), (66, 's'), (69, 's')],
#  [(38, 's'), (50, 's'), (66, 's'), (69, 's')],
#  [(38, 's'), (50, 's'), (66, 's'), (69, 's')],
#  [(38, 's'), (50, 's'), (69, 's')],
#  [(67, 'b')],
#  [(67, 's')],
#  [],
#  [(43, 'b'), (55, 'b'), (62, 'b'), (71, 'b')],
#  [(43, 's'), (55, 's'), (62, 's'), (71, 's')],
#  [(43, 's'), (55, 's'), (62, 's'), (71, 's')],
#  [(43, 's'), (55, 's'), (62, 's'), (71, 's')],
#  [(43, 'b'), (55, 'b'), (62, 'b'), (71, 'b')],
#  [(43, 's'), (55, 's'), (62, 's'), (71, 's')],
#  [(43, 'b'), (55, 'b'), (62, 'b'), (71, 'b')],
#  [(43, 's'), (55, 's'), (62, 's'), (71, 's')],
#  [(43, 's'), (55, 's'), (62, 's'), (71, 's')],
#  [(43, 's'), (55, 's'), (62, 's'), (71, 's')],
#  [(42, 'b'), (54, 'b'), (62, 'b'), (69, 'b')],
#  [(42, 's'), (54, 's'), (62, 's'), (69, 's')],
#  [(54, 's'), (69, 's')],
#  [(40, 'b'), (52, 'b'), (67, 'b'), (72, 'b')],
#  [(40, 's'), (52, 's'), (67, 's'), (72, 's')],
#  [(40, 'b'), (52, 'b'), (67, 's'), (72, 's')],
#  [(40, 's'), (52, 's'), (67, 's'), (72, 's')],
#  [(52, 's'), (67, 's'), (72, 's')],
#  [(42, 'b'), (54, 'b'), (67, 's'), (72, 's')],
#  [(42, 's'), (54, 's'), (67, 's'), (72, 's')],
#  [(54, 's'), (67, 's'), (72, 's')],
#  [(43, 'b'), (55, 'b'), (67, 'b'), (71, 'b')],
#  [(43, 's'), (55, 's'), (67, 's'), (71, 's')],
#  [(43, 's'), (55, 's'), (67, 's'), (71, 's')],
#  [(43, 's'), (55, 's'), (67, 's'), (71, 's')],
#  [(35, 'b'), (47, 'b'), (74, 'b')],
#  [(35, 's'), (47, 's'), (74, 's')],
#  [(47, 's')],
#  [(40, 'b'), (52, 'b'), (67, 'b'), (71, 'b')],
#  [(40, 's'), (52, 's'), (67, 's'), (71, 's')],
#  [(40, 's'), (52, 's'), (67, 's'), (71, 's')],
#  [(40, 's'), (52, 's'), (67, 's'), (71, 's')],
#  [(40, 'b'), (52, 'b'), (67, 'b')],
#  [(40, 's'), (52, 's'), (67, 's')],
#  [(52, 's')],
#  [(36, 'b'), (48, 'b'), (66, 'b'), (69, 'b')],
#  [(36, 's'), (48, 's'), (66, 's'), (69, 's')],
#  [(48, 's'), (66, 's'), (69, 's')],
#  [(33, 'b'), (45, 'b'), (66, 's'), (69, 's')],
#  [(33, 's'), (45, 's'), (66, 's'), (71, 'b')],
#  [(33, 's'), (45, 's'), (71, 's')],
#  [(45, 's'), (71, 's')],
#  [(38, 'b'), (50, 'b'), (66, 'b'), (69, 'b'), (71, 's')],
#  [(38, 's'), (50, 's'), (66, 's'), (69, 's')],
#  [(38, 's'), (50, 's'), (66, 's'), (69, 's')],
#  [(38, 's'), (50, 's'), (69, 's')],
#  [(50, 's'), (69, 's')],
#  [(31, 'b'), (43, 'b'), (59, 'b'), (62, 'b'), (67, 'b')],
#  [(31, 's'), (43, 's'), (59, 's'), (62, 's'), (67, 's')],
#  [(43, 's'), (59, 's'), (62, 's'), (67, 's')],
#  [(38, 'b'), (59, 's'), (62, 's'), (67, 's')],
#  [(38, 's'), (59, 's'), (62, 's'), (67, 's')],
#  [(59, 's'), (62, 's'), (67, 's')],
#  [(35, 'b'), (59, 's'), (62, 's'), (67, 's')],
#  [(35, 's'), (59, 's'), (62, 's'), (67, 's')],
#  [(59, 's'), (62, 's'), (67, 's')],
#  [(31, 'b'), (43, 'b'), (59, 's'), (62, 's'), (67, 's')],
#  [(31, 's'), (43, 's'), (59, 's'), (62, 's'), (67, 's')],
#  [(31, 's'), (43, 's')],
#  [(31, 's'), (43, 's')],
#  [(71, 'b'), (74, 'b')],
#  [(71, 's'), (74, 's')],
#  [(43, 'b'), (55, 'b'), (71, 'b'), (74, 'b')],
#  [(43, 's'), (55, 's'), (71, 's'), (74, 's')],
#  [(43, 's'), (55, 's'), (71, 's'), (74, 's')],
#  [(43, 's'), (55, 's'), (71, 's'), (74, 's')],
#  [(43, 'b'), (55, 'b'), (67, 'b'), (71, 'b')],
#  [(43, 's'), (55, 's'), (67, 's'), (71, 's')],
#  [(55, 's'), (71, 's')],
#  [(36, 'b'), (48, 'b'), (72, 'b'), (76, 'b')],
#  [(36, 's'), (48, 's'), (72, 's'), (76, 's')],
#  [(36, 's'), (48, 's'), (72, 's'), (76, 's')],
#  [(36, 's'), (48, 's'), (72, 's'), (76, 's')],
#  [(36, 'b'), (48, 'b'), (72, 'b'), (76, 'b')],
#  [(36, 's'), (48, 's'), (72, 's'), (76, 's')],
#  [(48, 's'), (76, 's')],
#  [(43, 'b'), (55, 'b'), (71, 'b'), (74, 'b')],
#  [(43, 's'), (55, 's'), (71, 's'), (74, 's')],
#  [(55, 's'), (71, 's'), (74, 's')],
#  [(47, 'b'), (55, 's'), (71, 's'), (74, 's')],
#  [(47, 's'), (55, 's'), (71, 's'), (74, 's')],
#  [(55, 's'), (71, 's'), (74, 's')],
#  [(50, 'b'), (55, 's'), (71, 's'), (74, 's')],
#  [(50, 's'), (55, 's'), (71, 's'), (74, 's')],
#  [(55, 's'), (71, 's'), (74, 's')],
#  [(43, 'b'), (55, 'b'), (71, 'b'), (74, 'b')],
#  [(43, 's'), (55, 's'), (71, 's'), (74, 's')],
#  [(43, 's'), (55, 's'), (71, 's'), (74, 's')],
#  [(43, 's'), (55, 's'), (71, 's'), (74, 's')],
#  [(71, 'b'), (74, 'b')],
#  [(71, 's'), (74, 's')],
#  [(43, 'b'), (55, 'b'), (71, 'b'), (74, 'b')],
#  [(43, 's'), (55, 's'), (71, 's'), (74, 's')],
#  [(43, 's'), (55, 's'), (71, 's'), (74, 's')],
#  [(43, 's'), (55, 's'), (71, 's'), (74, 's')],
#  [(43, 'b'), (55, 'b'), (67, 'b'), (71, 'b')],
#  [(43, 's'), (55, 's'), (67, 's'), (71, 's')],
#  [(55, 's'), (71, 's')],
#  [(36, 'b'), (48, 'b'), (72, 'b'), (76, 'b')],
#  [(36, 's'), (48, 's'), (72, 's'), (76, 's')],
#  [(36, 's'), (48, 's'), (72, 's'), (76, 's')],
#  [(36, 's'), (48, 's'), (72, 's'), (76, 's')],
#  [(36, 'b'), (48, 'b'), (72, 'b'), (76, 'b')],
#  [(36, 's'), (48, 's'), (72, 's'), (76, 's')],
#  [(48, 's')],
#  [(31, 'b'), (43, 'b'), (71, 'b'), (76, 'b')],
#  [(31, 's'), (43, 's'), (71, 's'), (74, 'b'), (76, 's')],
#  [(31, 's'), (43, 's'), (71, 's'), (74, 's')],
#  [(31, 's'), (43, 's'), (71, 's'), (74, 's'), (76, 'b')],
#  [(31, 's'), (43, 's'), (71, 's'), (76, 's')],
#  [(31, 's'), (35, 'b'), (43, 's'), (71, 's'), (76, 's')],
#  [(31, 's'), (35, 's'), (71, 's'), (76, 's')],
#  [(31, 's'), (35, 's'), (71, 's'), (74, 'b'), (76, 's')],
#  [(31, 's'), (35, 's'), (71, 's'), (74, 's')],
#  [(31, 's'), (35, 's'), (38, 'b'), (71, 's'), (74, 's')],
#  [(31, 's'), (38, 's'), (71, 's'), (74, 's')],
#  [(31, 's'), (38, 's'), (43, 'b'), (71, 's'), (74, 's')],
#  [(31, 's'), (43, 's'), (71, 's'), (74, 's')],
#  [(31, 's'), (38, 'b'), (43, 's'), (71, 's'), (74, 's')],
#  [(31, 's'), (38, 's'), (71, 's'), (74, 's')],
#  [(31, 's'), (35, 'b'), (38, 's'), (71, 's'), (74, 's')],
#  [(31, 's'), (35, 's'), (71, 's'), (74, 's')],
#  [(31, 's'), (71, 's'), (74, 's')],
#  [(31, 'b'), (43, 'b'), (71, 's'), (74, 's')],
#  [(31, 's'), (43, 's'), (71, 's'), (74, 's')],
#  [(31, 's'), (43, 's')],
#  [(31, 's'), (43, 's')],
#  [(67, 'b')],
#  [(67, 's')],
#  [],
#  [(43, 'b'), (55, 'b'), (62, 'b'), (71, 'b')],
#  [(43, 's'), (55, 's'), (62, 's'), (71, 's')],
#  [(43, 's'), (55, 's'), (62, 's'), (71, 's')],
#  [(43, 's'), (55, 's'), (62, 's'), (71, 's')],
#  [(43, 'b'), (55, 'b'), (62, 'b'), (71, 'b')],
#  [(43, 's'), (55, 's'), (62, 's'), (71, 's')],
#  [(43, 'b'), (55, 'b'), (62, 'b'), (71, 'b')],
#  [(43, 's'), (55, 's'), (62, 's'), (71, 's')],
#  [(43, 's'), (55, 's'), (62, 's'), (71, 's')],
#  [(43, 's'), (55, 's'), (62, 's'), (71, 's')],
#  [(42, 'b'), (54, 'b'), (62, 'b'), (69, 'b')],
#  [(42, 's'), (54, 's'), (62, 's'), (69, 's')],
#  [(54, 's'), (69, 's')],
#  [(40, 'b'), (52, 'b'), (67, 'b'), (72, 'b')],
#  [(40, 's'), (52, 's'), (67, 's'), (72, 's')],
#  [(40, 'b'), (52, 'b'), (67, 's'), (72, 's')],
#  [(40, 's'), (52, 's'), (67, 's'), (72, 's')],
#  [(52, 's'), (67, 's'), (72, 's')],
#  [(42, 'b'), (54, 'b'), (67, 's'), (72, 's')],
#  [(42, 's'), (54, 's'), (67, 's'), (72, 's')],
#  [(54, 's'), (67, 's'), (72, 's')],
#  [(43, 'b'), (55, 'b'), (67, 'b'), (71, 'b')],
#  [(43, 's'), (55, 's'), (67, 's'), (71, 's')],
#  [(43, 's'), (55, 's'), (67, 's'), (71, 's')],
#  [(43, 's'), (55, 's'), (69, 'b'), (72, 'b')],
#  [(43, 's'), (55, 's'), (72, 's')],
#  [(43, 'b'), (55, 'b'), (67, 'b'), (71, 'b')],
#  [(43, 's'), (55, 's'), (67, 's'), (71, 's')],
#  [(55, 's'), (71, 's')],
#  [(38, 'b'), (50, 'b'), (66, 'b'), (69, 'b')],
#  [(38, 's'), (50, 's'), (66, 's'), (69, 's')],
#  [(38, 's'), (50, 's'), (66, 's'), (69, 's')],
#  [(38, 's'), (50, 's'), (66, 's'), (69, 's')],
#  [(38, 'b'), (50, 'b'), (66, 'b'), (69, 'b')],
#  [(38, 's'), (50, 's'), (66, 's'), (69, 's')],
#  [(38, 'b'), (50, 'b'), (66, 'b'), (69, 'b')],
#  [(38, 's'), (50, 's'), (66, 's'), (69, 's')],
#  [(38, 's'), (50, 's'), (66, 's'), (69, 's')],
#  [(38, 's'), (50, 's'), (64, 'b'), (67, 'b')],
#  [(38, 's'), (50, 's'), (67, 's')],
#  [(38, 'b'), (50, 'b'), (66, 'b'), (69, 'b')],
#  [(38, 's'), (50, 's'), (66, 's'), (69, 's')],
#  [(50, 's'), (69, 's')],
#  [(31, 'b'), (43, 'b'), (67, 'b'), (71, 'b')],
#  [(31, 's'), (43, 's'), (67, 's'), (71, 's')],
#  [(43, 's'), (67, 's'), (71, 's')],
#  [(35, 'b'), (43, 's'), (67, 's'), (71, 's')],
#  [(35, 's'), (43, 's'), (67, 's'), (71, 's')],
#  [(43, 's'), (67, 's'), (71, 's')],
#  [(31, 'b'), (43, 's'), (67, 's'), (71, 's')],
#  [(31, 's'), (43, 's'), (67, 's'), (71, 's')],
#  [(43, 's'), (67, 's'), (71, 's')],
#  [(38, 'b'), (50, 'b'), (66, 'b'), (67, 's'), (69, 'b')],
#  [(38, 's'), (50, 's'), (66, 's'), (69, 's')],
#  [(38, 's'), (50, 's'), (66, 's'), (69, 's')],
#  [(38, 's'), (50, 's'), (66, 's'), (69, 's')],
#  [(38, 's'), (50, 's'), (66, 's'), (69, 's')],
#  [(38, 's'), (50, 's'), (69, 's')],
#  [(67, 'b')],
#  [(67, 's')],
#  [],
#  [(43, 'b'), (55, 'b'), (62, 'b'), (71, 'b')],
#  [(43, 's'), (55, 's'), (62, 's'), (71, 's')],
#  [(43, 's'), (55, 's'), (62, 's'), (71, 's')],
#  [(43, 's'), (55, 's'), (62, 's'), (71, 's')],
#  [(43, 'b'), (55, 'b'), (62, 'b'), (71, 'b')],
#  [(43, 's'), (55, 's'), (62, 's'), (71, 's')],
#  [(43, 'b'), (55, 'b'), (62, 'b'), (71, 'b')],
#  [(43, 's'), (55, 's'), (62, 's'), (71, 's')],
#  [(43, 's'), (55, 's'), (62, 's'), (71, 's')],
#  [(43, 's'), (55, 's'), (62, 's'), (71, 's')],
#  [(42, 'b'), (54, 'b'), (62, 'b'), (69, 'b')],
#  [(42, 's'), (54, 's'), (62, 's'), (69, 's')],
#  [(54, 's'), (69, 's')],
#  [(40, 'b'), (52, 'b'), (67, 'b'), (72, 'b')],
#  [(40, 's'), (52, 's'), (67, 's'), (72, 's')],
#  [(40, 'b'), (52, 'b'), (67, 's'), (72, 's')],
#  [(40, 's'), (52, 's'), (67, 's'), (72, 's')],
#  [(52, 's'), (67, 's'), (72, 's')],
#  [(42, 'b'), (54, 'b'), (67, 's'), (72, 's')],
#  [(42, 's'), (54, 's'), (67, 's'), (72, 's')],
#  [(54, 's'), (67, 's'), (72, 's')],
#  [(43, 'b'), (55, 'b'), (67, 'b'), (71, 'b')],
#  [(43, 's'), (55, 's'), (67, 's'), (71, 's')],
#  [(43, 's'), (55, 's'), (67, 's'), (71, 's')],
#  [(43, 's'), (55, 's'), (67, 's'), (71, 's')],
#  [(35, 'b'), (47, 'b'), (74, 'b')],
#  [(35, 's'), (47, 's'), (74, 's')],
#  [(47, 's')],
#  [(40, 'b'), (52, 'b'), (67, 'b'), (71, 'b')],
#  [(40, 's'), (52, 's'), (67, 's'), (71, 's')],
#  [(40, 's'), (52, 's'), (67, 's'), (71, 's')],
#  [(40, 's'), (52, 's'), (67, 's'), (71, 's')],
#  [(40, 'b'), (52, 'b'), (67, 'b')],
#  [(40, 's'), (52, 's'), (67, 's')],
#  [(52, 's')],
#  [(36, 'b'), (48, 'b'), (66, 'b'), (69, 'b')],
#  [(36, 's'), (48, 's'), (66, 's'), (69, 's')],
#  [(48, 's'), (66, 's'), (69, 's')],
#  [(33, 'b'), (45, 'b'), (66, 's'), (69, 's')],
#  [(33, 's'), (45, 's'), (66, 's'), (71, 'b')],
#  [(33, 's'), (45, 's'), (71, 's')],
#  [(45, 's'), (71, 's')],
#  [(38, 'b'), (50, 'b'), (66, 'b'), (69, 'b'), (71, 's')],
#  [(38, 's'), (50, 's'), (66, 's'), (69, 's')],
#  [(38, 's'), (50, 's'), (66, 's'), (69, 's')],
#  [(38, 's'), (50, 's'), (69, 's')],
#  [(50, 's'), (69, 's')],
#  [(31, 'b'), (43, 'b'), (59, 'b'), (62, 'b'), (67, 'b')],
#  [(43, 's'), (59, 's'), (62, 's'), (67, 's')],
#  [(38, 'b'), (59, 's'), (62, 's'), (67, 's')],
#  [(59, 's'), (62, 's'), (67, 's')],
#  [(35, 'b'), (59, 's'), (62, 's'), (67, 's')],
#  [(59, 's'), (62, 's'), (67, 's')],
#  [(31, 'b'), (43, 'b'), (59, 's'), (62, 's'), (67, 's')],
#  [(31, 's'), (43, 's'), (59, 's'), (62, 's'), (67, 's')],
#  [(31, 's'), (43, 's')],
#  [(67, 'b')],
#  [(67, 's')],
#  [(55, 'b'), (71, 'b')],
#  [(55, 's'), (71, 's')],
#  [(55, 's'), (71, 's')],
#  [(55, 's'), (72, 'b')],
#  [(55, 's')],
#  [(43, 'b'), (71, 'b')],
#  [(43, 's'), (71, 's')],
#  [(71, 's')],
#  [(55, 'b'), (71, 'b')],
#  [(55, 's'), (71, 's')],
#  [(55, 's'), (71, 's')],
#  [(55, 's'), (72, 'b')],
#  [(55, 's')],
#  [(54, 'b'), (69, 'b')],
#  [(54, 's'), (69, 's')],
#  [],
#  [(52, 'b'), (72, 'b')],
#  [(52, 's'), (72, 's')],
#  [(52, 's'), (72, 's')],
#  [(52, 's'), (74, 'b')],
#  [(52, 's')],
#  [(54, 'b'), (72, 'b')],
#  [(54, 's'), (72, 's')],
#  [],
#  [(55, 'b'), (71, 'b')],
#  [(55, 's'), (71, 's')],
#  [(55, 's'), (71, 's')],
#  [(55, 's'), (72, 'b')],
#  [(55, 's')],
#  [(43, 'b'), (71, 'b')],
#  [(43, 's'), (71, 's')],
#  [],
#  [(50, 'b'), (69, 'b')],
#  [(50, 's'), (69, 's')],
#  [(50, 's'), (69, 's')],
#  [(50, 's'), (71, 'b')],
#  [(50, 's')],
#  [(52, 'b'), (69, 'b')],
#  [(52, 's'), (69, 's')],
#  [(69, 's')],
#  [(54, 'b'), (69, 'b')],
#  [(54, 's'), (69, 's')],
#  [(54, 's'), (69, 's')],
#  [(54, 's'), (67, 'b')],
#  [(54, 's')],
#  [(50, 'b'), (69, 'b')],
#  [(50, 's'), (69, 's')],
#  [],
#  [(55, 'b'), (71, 'b')],
#  [(55, 's'), (71, 's')],
#  [(55, 's'), (71, 's')],
#  [(55, 's'), (72, 'b')],
#  [(55, 's')],
#  [(43, 'b'), (71, 'b')],
#  [(43, 's'), (71, 's')],
#  [],
#  [(50, 'b'), (69, 'b')],
#  [(50, 's'), (69, 's')],
#  [(50, 's'), (69, 's')],
#  [(50, 's'), (69, 's')],
#  [(67, 'b')],
#  [(67, 's')],
#  [],
#  [(55, 'b'), (71, 'b')],
#  [(55, 's'), (71, 's')],
#  [(55, 's'), (71, 's')],
#  [(55, 's'), (72, 'b')],
#  [(55, 's')],
#  [(43, 'b'), (71, 'b')],
#  [(43, 's'), (71, 's')],
#  [(71, 's')],
#  [(55, 'b'), (71, 'b')],
#  [(55, 's'), (71, 's')],
#  [(55, 's'), (71, 's')],
#  [(55, 's'), (72, 'b')],
#  [(55, 's')],
#  [(54, 'b'), (69, 'b')],
#  [(54, 's'), (69, 's')],
#  [],
#  [(52, 'b'), (72, 'b')],
#  [(52, 's'), (72, 's')],
#  [(52, 's'), (72, 's')],
#  [(52, 's'), (74, 'b')],
#  [(52, 's')],
#  [(54, 'b'), (72, 'b')],
#  [(54, 's'), (72, 's')],
#  [],
#  [(55, 'b'), (71, 'b')],
#  [(55, 's'), (71, 's')],
#  [(55, 's'), (71, 's')],
#  [(55, 's'), (71, 's')],
#  [(47, 'b'), (74, 'b')],
#  [(47, 's'), (74, 's')],
#  [],
#  [(52, 'b'), (71, 'b')],
#  [(52, 's'), (71, 's')],
#  [(52, 's'), (71, 's')],
#  [(52, 's'), (69, 'b')],
#  [(52, 's')],
#  [(52, 'b'), (67, 'b')],
#  [(52, 's'), (67, 's')],
#  [],
#  [(48, 'b'), (69, 'b')],
#  [(48, 's'), (69, 's')],
#  [(48, 's'), (69, 's')],
#  [(48, 's'), (71, 'b')],
#  [(48, 's')],
#  [(50, 'b'), (69, 'b')],
#  [(50, 's'), (69, 's')],
#  [],
#  [(55, 'b'), (67, 'b')],
#  [(55, 's'), (67, 's')],
#  [(55, 's'), (67, 's')],
#  [(55, 's'), (62, 'b')],
#  [(55, 's')],
#  [(50, 'b'), (59, 'b')],
#  [(50, 's'), (59, 's')],
#  [],
#  [(43, 'b'), (55, 'b')],
#  [(43, 's'), (55, 's')],
#  [(43, 's'), (55, 's')],
#  [(43, 's'), (55, 's')],
#  [(74, 'b')],
#  [(74, 's')],
#  [(67, 'b'), (74, 'b')],
#  [(67, 's'), (74, 's')],
#  [(67, 's'), (74, 's')],
#  [(67, 's'), (72, 'b')],
#  [(67, 's')],
#  [(55, 'b'), (71, 'b')],
#  [(55, 's'), (71, 's')],
#  [],
#  [(60, 'b'), (76, 'b')],
#  [(60, 's'), (76, 's')],
#  [(60, 's'), (76, 's')],
#  [(60, 's'), (78, 'b')],
#  [(60, 's')],
#  [(48, 'b'), (76, 'b')],
#  [(48, 's'), (76, 's')],
#  [],
#  [(55, 'b'), (74, 'b')],
#  [(55, 's'), (74, 's')],
#  [(55, 's'), (74, 's')],
#  [(50, 'b'), (74, 's')],
#  [(74, 's')],
#  [(47, 'b'), (74, 'b')],
#  [(47, 's'), (74, 's')],
#  [(74, 's')],
#  [(43, 'b'), (74, 'b')],
#  [(43, 's'), (74, 's')],
#  [(43, 's'), (74, 's')],
#  [(43, 's'), (74, 's')],
#  [(74, 'b')],
#  [(74, 's')],
#  [(55, 'b'), (74, 'b')],
#  [(55, 's'), (74, 's')],
#  [(55, 's'), (74, 's')],
#  [(55, 's'), (72, 'b')],
#  [(55, 's')],
#  [(43, 'b'), (71, 'b')],
#  [(43, 's'), (71, 's')],
#  [],
#  [(48, 'b'), (76, 'b')],
#  [(48, 's'), (76, 's')],
#  [(48, 's'), (76, 's')],
#  [(48, 's'), (78, 'b')],
#  [(48, 's')],
#  [(36, 'b'), (79, 'b')],
#  [(36, 's'), (79, 's')],
#  [],
#  [(43, 'b'), (76, 'b')],
#  [(43, 's'), (74, 'b'), (76, 's')],
#  [(43, 's'), (74, 's')],
#  [(43, 's'), (74, 's'), (76, 'b')],
#  [(43, 's'), (76, 's')],
#  [(43, 's'), (74, 'b'), (76, 's')],
#  [(43, 's'), (74, 's')],
#  [(43, 's'), (74, 's')],
#  [(38, 'b'), (74, 's')],
#  [(74, 's')],
#  [(35, 'b'), (74, 's')],
#  [(35, 's'), (74, 's')],
#  [(74, 's')],
#  [(31, 'b'), (43, 'b'), (74, 's')],
#  [(31, 's'), (43, 's'), (74, 's')],
#  [(31, 's'), (43, 's')],
#  [(31, 's'), (43, 's')],
#  [(67, 'b')],
#  [(67, 's')],
#  [],
#  [(43, 'b'), (71, 'b')],
#  [(43, 's'), (71, 's')],
#  [(43, 's'), (71, 's')],
#  [(43, 's'), (72, 'b')],
#  [(43, 's')],
#  [(43, 'b'), (71, 'b')],
#  [(43, 's'), (71, 's')],
#  [(43, 'b'), (71, 'b')],
#  [(43, 's'), (71, 's')],
#  [(43, 's'), (71, 's')],
#  [(43, 's'), (72, 'b')],
#  [(43, 's')],
#  [(42, 'b'), (69, 'b')],
#  [(42, 's'), (69, 's')],
#  [],
#  [(40, 'b'), (72, 'b')],
#  [(40, 's'), (72, 's')],
#  [(40, 's'), (72, 's')],
#  [(40, 's'), (74, 'b')],
#  [(40, 's')],
#  [(42, 'b'), (72, 'b')],
#  [(42, 's'), (72, 's')],
#  [],
#  [(43, 'b'), (71, 'b')],
#  [(43, 's'), (71, 's')],
#  [(43, 's'), (71, 's')],
#  [(43, 's'), (72, 'b')],
#  [(43, 's')],
#  [(31, 'b'), (71, 'b')],
#  [(31, 's'), (71, 's')],
#  [],
#  [(38, 'b'), (69, 'b')],
#  [(38, 's'), (69, 's')],
#  [(38, 's'), (69, 's')],
#  [(38, 's'), (71, 'b')],
#  [(38, 's')],
#  [(40, 'b'), (69, 'b')],
#  [(40, 's'), (69, 's')],
#  [(69, 's')],
#  [(42, 'b'), (69, 'b')],
#  [(42, 's'), (69, 's')],
#  [(42, 's'), (69, 's')],
#  [(42, 's'), (67, 'b')],
#  [(42, 's')],
#  [(38, 'b'), (69, 'b')],
#  [(38, 's'), (69, 's')],
#  [],
#  [(43, 'b'), (71, 'b')],
#  [(43, 's'), (71, 's')],
#  [(43, 's'), (71, 's')],
#  [(43, 's'), (72, 'b')],
#  [(43, 's')],
#  [(31, 'b'), (71, 'b')],
#  [(31, 's'), (71, 's')],
#  [],
#  [(38, 'b'), (69, 'b')],
#  [(38, 's'), (69, 's')],
#  [(38, 's'), (69, 's')],
#  [(38, 's'), (69, 's')],
#  [(67, 'b')],
#  [(67, 's')],
#  [],
#  [(43, 'b'), (71, 'b')],
#  [(43, 's'), (71, 's')],
#  [(43, 's'), (71, 's')],
#  [(43, 's'), (72, 'b')],
#  [(43, 's')],
#  [(43, 'b'), (71, 'b')],
#  [(43, 's'), (71, 's')],
#  [(43, 'b'), (71, 'b')],
#  [(43, 's'), (71, 's')],
#  [(43, 's'), (71, 's')],
#  [(43, 's'), (72, 'b')],
#  [(43, 's')],
#  [(42, 'b'), (69, 'b')],
#  [(42, 's'), (69, 's')],
#  [],
#  [(40, 'b'), (72, 'b')],
#  [(40, 's'), (72, 's')],
#  [(40, 's'), (72, 's')],
#  [(40, 's'), (74, 'b')],
#  [(40, 's')],
#  [(42, 'b'), (72, 'b')],
#  [(42, 's'), (72, 's')],
#  [],
#  [(43, 'b'), (71, 'b')],
#  [(43, 's'), (71, 's')],
#  [(43, 's'), (71, 's')],
#  [(43, 's'), (71, 's')],
#  [(35, 'b'), (74, 'b')],
#  [(35, 's'), (74, 's')],
#  [],
#  [(40, 'b'), (71, 'b')],
#  [(40, 's'), (71, 's')],
#  [(40, 's'), (71, 's')],
#  [(40, 's'), (69, 'b')],
#  [(40, 's')],
#  [(40, 'b'), (67, 'b')],
#  [(40, 's'), (67, 's')],
#  [],
#  [(36, 'b'), (69, 'b')],
#  [(36, 's'), (69, 's')],
#  [(36, 's'), (69, 's')],
#  [(36, 's'), (71, 'b')],
#  [(36, 's')],
#  [(38, 'b'), (69, 'b')],
#  [(38, 's'), (69, 's')],
#  [(43, 'b'), (67, 'b')],
#  [(43, 's'), (62, 'b')],
#  [(43, 's')],
#  [(38, 'b'), (59, 'b')],
#  [],
#  [(31, 'b'), (43, 'b'), (55, 'b')],
#  [(31, 's'), (43, 's'), (55, 's')],
#  [(31, 's'), (43, 's'), (55, 's')],
#  [(67, 'b')],
#  [(67, 's')],
#  [(55, 'b'), (71, 'b')],
#  [(55, 's'), (71, 's')],
#  [(55, 's'), (71, 's')],
#  [(59, 'b'), (71, 's')],
#  [(71, 's')],
#  [(62, 'b'), (71, 'b')],
#  [(62, 's'), (71, 's')],
#  [(71, 's')],
#  [(55, 'b'), (71, 'b')],
#  [(55, 's'), (71, 's')],
#  [(55, 's'), (71, 's')],
#  [(59, 'b'), (71, 's')],
#  [(71, 's')],
#  [(62, 'b'), (69, 'b')],
#  [(62, 's'), (69, 's')],
#  [],
#  [(54, 'b'), (72, 'b')],
#  [(54, 's'), (72, 's')],
#  [(54, 's'), (72, 's')],
#  [(57, 'b'), (72, 's')],
#  [(72, 's')],
#  [(62, 'b'), (72, 's')],
#  [(62, 's'), (72, 's')],
#  [(72, 's')],
#  [(55, 'b'), (71, 'b')],
#  [(55, 's'), (71, 's')],
#  [(55, 's'), (71, 's')],
#  [(59, 'b'), (72, 'b')],
#  [],
#  [(62, 'b'), (71, 'b')],
#  [(62, 's'), (71, 's')],
#  [],
#  [(50, 'b'), (69, 'b')],
#  [(50, 's'), (69, 's')],
#  [(50, 's'), (69, 's')],
#  [(57, 'b'), (69, 's')],
#  [(69, 's')],
#  [(62, 'b'), (69, 'b')],
#  [(62, 's'), (69, 's')],
#  [(69, 's')],
#  [(50, 'b'), (69, 'b')],
#  [(50, 's'), (69, 's')],
#  [(50, 's'), (69, 's')],
#  [(57, 'b'), (67, 'b')],
#  [],
#  [(62, 'b'), (69, 'b')],
#  [(62, 's'), (69, 's')],
#  [],
#  [(55, 'b'), (72, 'b')],
#  [(55, 's'), (71, 'b'), (72, 's')],
#  [(55, 's'), (71, 's')],
#  [(55, 's'), (71, 's'), (72, 'b')],
#  [(55, 's'), (72, 's')],
#  [(55, 's'), (71, 'b'), (72, 's')],
#  [(55, 's'), (71, 's')],
#  [(55, 's'), (71, 's')],
#  [(59, 'b'), (71, 's')],
#  [(71, 's')],
#  [(62, 'b'), (71, 's')],
#  [(62, 's'), (71, 's')],
#  [(71, 's')],
#  [],
#  [(50, 'b'), (69, 'b')],
#  [(50, 's'), (69, 's')],
#  [(50, 's'), (69, 's')],
#  [(50, 's'), (69, 's')],
#  [(67, 'b')],
#  [(67, 's')],
#  [],
#  [(55, 'b'), (71, 'b')],
#  [(55, 's'), (71, 's')],
#  [(55, 's'), (71, 's')],
#  [(59, 'b'), (71, 's')],
#  [(71, 's')],
#  [(62, 'b'), (71, 'b')],
#  [(62, 's'), (71, 's')],
#  [(71, 's')],
#  [(55, 'b'), (71, 'b')],
#  [(55, 's'), (71, 's')],
#  [(55, 's'), (71, 's')],
#  [(59, 'b'), (71, 's')],
#  [(71, 's')],
#  [(62, 'b'), (69, 'b')],
#  [(62, 's'), (69, 's')],
#  [],
#  [(54, 'b'), (72, 'b')],
#  [(54, 's'), (72, 's')],
#  [(54, 's'), (72, 's')],
#  [(57, 'b'), (72, 's')],
#  [(72, 's')],
#  [(62, 'b'), (72, 's')],
#  [(62, 's'), (72, 's')],
#  [(72, 's')],
#  [(55, 'b'), (71, 'b')],
#  [(55, 's'), (71, 's')],
#  [(55, 's'), (71, 's')],
#  [(59, 'b'), (71, 's')],
#  [(71, 's')],
#  [(62, 'b'), (74, 'b')],
#  [(62, 's'), (74, 's')],
#  [],
#  [(52, 'b'), (71, 'b')],
#  [(52, 's'), (71, 's')],
#  [(52, 's'), (71, 's')],
#  [(55, 'b'), (71, 's')],
#  [(71, 's')],
#  [(59, 'b'), (67, 'b')],
#  [(59, 's'), (67, 's')],
#  [],
#  [(50, 'b'), (69, 'b')],
#  [(50, 's'), (69, 's')],
#  [(50, 's'), (69, 's')],
#  [(57, 'b'), (71, 'b')],
#  [],
#  [(60, 'b'), (69, 'b')],
#  [(60, 's'), (69, 's')],
#  [],
#  [(55, 'b'), (67, 'b')],
#  [(55, 's'), (67, 's')],
#  [(55, 's'), (67, 's')],
#  [(50, 'b'), (67, 's')],
#  [(67, 's')],
#  [(47, 'b'), (67, 's')],
#  [(47, 's'), (67, 's')],
#  [(67, 's')],
#  [(43, 'b'), (67, 's')],
#  [(43, 's'), (67, 's')],
#  [(43, 's')],
#  [(43, 's')],
#  [(74, 'b')],
#  [(74, 's')],
#  [(59, 'b'), (74, 'b')],
#  [(59, 's'), (74, 's')],
#  [(59, 's'), (74, 's')],
#  [(62, 'b'), (74, 's')],
#  [(74, 's')],
#  [(67, 'b'), (71, 'b')],
#  [(67, 's'), (71, 's')],
#  [],
#  [(60, 'b'), (76, 'b')],
#  [(60, 's'), (76, 's')],
#  [(60, 's'), (76, 's')],
#  [(64, 'b'), (76, 's')],
#  [(76, 's')],
#  [(67, 'b'), (76, 'b')],
#  [(67, 's'), (76, 's')],
#  [],
#  [(59, 'b'), (74, 'b')],
#  [(59, 's'), (74, 's')],
#  [(59, 's'), (74, 's')],
#  [(62, 'b'), (74, 's')],
#  [(74, 's')],
#  [(67, 'b'), (74, 's')],
#  [(67, 's'), (74, 's')],
#  [(74, 's')],
#  [(55, 'b'), (74, 'b')],
#  [(55, 's'), (74, 's')],
#  [(55, 's'), (74, 's')],
#  [(55, 's'), (74, 's')],
#  [(74, 'b')],
#  [(74, 's')],
#  [(47, 'b'), (74, 'b')],
#  [(47, 's'), (74, 's')],
#  [(47, 's'), (74, 's')],
#  [(50, 'b'), (74, 's')],
#  [(74, 's')],
#  [(55, 'b'), (71, 'b')],
#  [(55, 's'), (71, 's')],
#  [],
#  [(48, 'b'), (76, 'b')],
#  [(48, 's'), (76, 's')],
#  [(48, 's'), (76, 's')],
#  [(52, 'b'), (76, 's')],
#  [(76, 's')],
#  [(55, 'b'), (76, 'b')],
#  [(55, 's'), (76, 's')],
#  [(76, 's')],
#  [(43, 'b'), (76, 'b')],
#  [(43, 's'), (74, 'b'), (76, 's')],
#  [(43, 's'), (74, 's')],
#  [(43, 's'), (74, 's'), (76, 'b')],
#  [(43, 's'), (76, 's')],
#  [(43, 's'), (74, 'b'), (76, 's')],
#  [(43, 's'), (74, 's')],
#  [(43, 's'), (74, 's')],
#  [(47, 'b'), (74, 's')],
#  [(74, 's')],
#  [(50, 'b'), (74, 's')],
#  [(50, 's'), (74, 's')],
#  [(74, 's')],
#  [(43, 'b'), (55, 'b'), (74, 's')],
#  [(43, 's'), (55, 's'), (74, 's')],
#  [(43, 's'), (55, 's')],
#  [(43, 's'), (55, 's')],
#  [(67, 'b')],
#  [(67, 's')],
#  [],
#  [(43, 'b'), (71, 'b')],
#  [(43, 's'), (71, 's')],
#  [(43, 's'), (71, 's')],
#  [(47, 'b'), (71, 's')],
#  [(71, 's')],
#  [(50, 'b'), (71, 'b')],
#  [(50, 's'), (71, 's')],
#  [(71, 's')],
#  [(43, 'b'), (71, 'b')],
#  [(43, 's'), (71, 's')],
#  [(43, 's'), (71, 's')],
#  [(47, 'b'), (71, 's')],
#  [(71, 's')],
#  [(50, 'b'), (69, 'b')],
#  [(50, 's'), (69, 's')],
#  [],
#  [(42, 'b'), (72, 'b')],
#  [(42, 's'), (72, 's')],
#  [(42, 's'), (72, 's')],
#  [(45, 'b'), (72, 's')],
#  [(72, 's')],
#  [(50, 'b'), (72, 's')],
#  [(50, 's'), (72, 's')],
#  [(72, 's')],
#  [(43, 'b'), (71, 'b')],
#  [(43, 's'), (71, 's')],
#  [(43, 's'), (71, 's')],
#  [(47, 'b'), (72, 'b')],
#  [],
#  [(50, 'b'), (71, 'b')],
#  [(50, 's'), (71, 's')],
#  [],
#  [(38, 'b'), (69, 'b')],
#  [(38, 's'), (69, 's')],
#  [(38, 's'), (69, 's')],
#  [(45, 'b'), (69, 's')],
#  [(69, 's')],
#  [(50, 'b'), (69, 'b')],
#  [(50, 's'), (69, 's')],
#  [(69, 's')],
#  [(38, 'b'), (69, 'b')],
#  [(38, 's'), (69, 's')],
#  [(38, 's'), (69, 's')],
#  [(45, 'b'), (67, 'b')],
#  [],
#  [(50, 'b'), (69, 'b')],
#  [(50, 's'), (69, 's')],
#  [],
#  [(43, 'b'), (72, 'b')],
#  [(43, 's'), (71, 'b'), (72, 's')],
#  [(43, 's'), (71, 's')],
#  [(43, 's'), (71, 's'), (72, 'b')],
#  [(43, 's'), (72, 's')],
#  [(43, 's'), (71, 'b'), (72, 's')],
#  [(43, 's'), (71, 's')],
#  [(43, 's'), (71, 's')],
#  [(47, 'b'), (71, 's')],
#  [(71, 's')],
#  [(50, 'b'), (71, 's')],
#  [(50, 's'), (71, 's')],
#  [(71, 's')],
#  [],
#  [(38, 'b'), (69, 'b')],
#  [(38, 's'), (69, 's')],
#  [(38, 's'), (69, 's')],
#  [(38, 's'), (69, 's')],
#  [(67, 'b')],
#  [(67, 's')],
#  [],
#  [(43, 'b'), (71, 'b')],
#  [(43, 's'), (71, 's')],
#  [(43, 's'), (71, 's')],
#  [(47, 'b'), (71, 's')],
#  [(71, 's')],
#  [(50, 'b'), (71, 'b')],
#  [(50, 's'), (71, 's')],
#  [(71, 's')],
#  [(43, 'b'), (71, 'b')],
#  [(43, 's'), (71, 's')],
#  [(43, 's'), (71, 's')],
#  [(47, 'b'), (71, 's')],
#  [(71, 's')],
#  [(50, 'b'), (69, 'b')],
#  [(50, 's'), (69, 's')],
#  [],
#  [(42, 'b'), (72, 'b')],
#  [(42, 's'), (72, 's')],
#  [(42, 's'), (72, 's')],
#  [(45, 'b'), (72, 's')],
#  [(72, 's')],
#  [(50, 'b'), (72, 's')],
#  [(50, 's'), (72, 's')],
#  [(72, 's')],
#  [(43, 'b'), (71, 'b')],
#  [(43, 's'), (71, 's')],
#  [(43, 's'), (71, 's')],
#  [(47, 'b'), (71, 's')],
#  [(71, 's')],
#  [(50, 'b'), (74, 'b')],
#  [(50, 's'), (74, 's')],
#  [],
#  [(40, 'b'), (71, 'b')],
#  [(40, 's'), (71, 's')],
#  [(40, 's'), (71, 's')],
#  [(43, 'b'), (71, 's')],
#  [(71, 's')],
#  [(47, 'b'), (67, 'b')],
#  [(47, 's'), (67, 's')],
#  [],
#  [(38, 'b'), (69, 'b')],
#  [(38, 's'), (69, 's')],
#  [(38, 's'), (69, 's')],
#  [(45, 'b'), (71, 'b')],
#  [],
#  [(48, 'b'), (69, 'b')],
#  [(48, 's'), (69, 's')],
#  [(43, 'b'), (67, 'b')],
#  [(38, 'b'), (67, 's')],
#  [(67, 's')],
#  [(35, 'b'), (67, 's')],
#  [(67, 's')],
#  [(31, 'b'), (67, 's')],
#  [(31, 's'), (67, 's')],
#  [(31, 's')],
#  [(67, 'b')],
#  [],
#  [(69, 'b')],
#  [(55, 'b'), (71, 'b')],
#  [(55, 's')],
#  [(55, 's'), (67, 'b')],
#  [(55, 's')],
#  [(55, 's'), (62, 'b')],
#  [(55, 's')],
#  [(55, 's'), (67, 'b')],
#  [(55, 's')],
#  [(43, 'b'), (71, 'b')],
#  [(43, 's'), (71, 's')],
#  [(71, 's')],
#  [(55, 'b'), (71, 'b')],
#  [(55, 's')],
#  [(55, 's'), (74, 'b')],
#  [(55, 's')],
#  [(55, 's'), (72, 'b')],
#  [(55, 's')],
#  [(55, 's'), (71, 'b')],
#  [(55, 's')],
#  [(54, 'b'), (69, 'b')],
#  [(54, 's')],
#  [(54, 's'), (71, 'b')],
#  [(71, 's')],
#  [],
#  [(52, 'b'), (72, 'b')],
#  [(52, 's')],
#  [(52, 's'), (71, 'b')],
#  [(52, 's')],
#  [(52, 's'), (72, 'b')],
#  [(52, 's')],
#  [(52, 's'), (76, 'b')],
#  [(52, 's')],
#  [(54, 'b'), (74, 'b')],
#  [(54, 's')],
#  [(54, 's'), (72, 'b')],
#  [(72, 's')],
#  [(72, 'b')],
#  [(55, 'b'), (72, 's')],
#  [(55, 's'), (71, 'b'), (72, 's')],
#  [(55, 's'), (71, 's')],
#  [(55, 's'), (71, 's'), (72, 'b')],
#  [(55, 's'), (72, 's')],
#  [(55, 's'), (71, 'b'), (72, 's')],
#  [(55, 's'), (71, 's')],
#  [(55, 's')],
#  [(55, 's'), (74, 'b')],
#  [(55, 's')],
#  [(43, 'b'), (72, 'b')],
#  [(43, 's')],
#  [(43, 's'), (71, 'b')],
#  [(71, 's')],
#  [],
#  [(50, 'b'), (69, 'b')],
#  [(50, 's')],
#  [(50, 's'), (66, 'b')],
#  [(50, 's')],
#  ...]

# %%
list_of_a = [[(69, 'b')]]
list_of_a.extend([[(69, 's')]] * 5)
list_of_a.extend([[(69, 'c'), (73, 'b')]])
list_of_a.extend([[(73, 'c'), (69, 'c')]] * 4)

print list_of_a
# Out:
# [[(69, 'b')], [(69, 's')], [(69, 's')], [(69, 's')], [(69, 's')], [(69, 's')], [(69, 'c'), (73, 'b')], [(73, 'c'), (69, 'c')], [(73, 'c'), (69, 'c')], [(73, 'c'), (69, 'c')], [(73, 'c'), (69, 'c')]]

# %%
pba = Playback(list_of_a)

pba.output_playback_stream()

# %%
pb = Playback(parsed_midi.list_of_notes)

pb.output_playback_stream()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-f6c6fdf2635b> in <module>()
#       1 pb = Playback(parsed_midi.list_of_notes)
#       2
# ----> 3 pb.output_playback_stream()
#
# /Users/gavinpeterkin/workspace/music_composition/src/utility/playback.py in output_playback_stream(self)
#      76             for tone_generator in current_tones.values():
#      77                 output += tone_generator.get_next_samples(beat_length)
# ---> 78             stream.write(output / 12)
#      79             previous_active_notes = active_notes
#      80         stream.stop_stream()
#
# /Users/gavinpeterkin/.virtualenvs/music/lib/python2.7/site-packages/pyaudio.pyc in write(self, frames, num_frames, exception_on_underflow)
#     584
#     585         pa.write_stream(self._stream, frames, num_frames,
# --> 586                         exception_on_underflow)
#     587
#     588
#
# KeyboardInterrupt:

# %%
pb.get_note_freq(67)

# %%
np.linspace(0, 100, 100, dtype=np.float32)

# %%
pb.terminate()

# %%
import numpy as np

np.zeros()
